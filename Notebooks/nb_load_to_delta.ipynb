# %%
# Load raw Sales CSV file to Delta table in lh_sales
df = spark.read.format('csv') \
    .options(header='true', inferSchema='true') \
    .load('Files/raw/sales_data.csv')

df.write.format('delta').mode('overwrite').saveAsTable('bronze_sales')
# Out:
# StatementMeta(, a9b8dba7-bcfe-405c-a796-bdadb67900d5, 5, Finished, Available, Finished, False)
